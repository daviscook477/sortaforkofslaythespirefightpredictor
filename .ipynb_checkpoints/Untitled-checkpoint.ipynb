# %%
import os
import glob
import json
import random
from multiprocessing import Pool
from tqdm import tqdm

data_path = r'C:\Users\davis\Documents\Slay the Spire Runs\2020-12-13'


def process_file(file_path):
    file_datas = []
    with open(file_path) as f:
        runs = json.load(f)
        for run in runs:
            if len(run) > 0:
                file_datas.append(random.choice(run))
    return file_datas


print('Looking for json data files')
file_paths = glob.glob(os.path.join(data_path, '*.json'))
print(f'Found {len(file_paths)} data files')

datas = []
for file_path in tqdm(file_paths):
    datas.extend(process_file(file_path))

print(len(datas))
# Out:
#   0%|          | 0/72 [00:00<?, ?it/s]
# Looking for json data files
# Found 72 data files
# 100%|██████████| 72/72 [00:19<00:00,  3.63it/s]
# 65575

# %%
def upgrade_card(card_str):
    """
    Upgrades a card. Ex: Clash->Clash+1
    :param card_str: the name of the card to upgrade
    :return: the name of the card after it is upgraded
    """
    return card_str + '+1'


# the relics in the vanilla game
BASE_GAME_RELICS = {
    'Burning Blood', 'Cracked Core', 'PureWater', 'Ring of the Snake',
    'Akabeko', 'Anchor', 'Ancient Tea Set', 'Art of War', 'Bag of Marbles',
    'Bag of Preparation', 'Blood Vial',
    'Bronze Scales', 'Centennial Puzzle', 'CeramicFish', 'Damaru', 'DataDisk',
    'Dream Catcher', 'Happy Flower', 'Juzu Bracelet', 'Lantern', 'MawBank',
    'MealTicket', 'Nunchaku', 'Oddly Smooth Stone', 'Omamori', 'Orichalcum',
    'Pen Nib', 'Potion Belt',
    'PreservedInsect', 'Red Skull', 'Regal Pillow',
    'Smiling Mask', 'Snake Skull',
    'Strawberry', 'Boot', 'Tiny Chest', 'Toy Ornithopter', 'Vajra',
    'War Paint', 'Whetstone', 'Blue Candle', 'Bottled Flame',
    'Bottled Lightning', 'Bottled Tornado', 'Darkstone Periapt', 'Yang',
    'Eternal Feather', 'Frozen Egg 2', 'Cables', 'Gremlin Horn', 'HornCleat',
    'InkBottle', 'Kunai', 'Letter Opener', 'Matryoshka', 'Meat on the Bone',
    'Mercury Hourglass', 'Molten Egg 2', 'Mummified Hand', 'Ninja Scroll',
    'Ornamental Fan', 'Pantograph', 'Paper Crane', 'Paper Frog', 'Pear',
    'Question Card', 'Self Forming Clay', 'Shuriken', 'Singing Bowl',
    'StrikeDummy', 'Sundial', 'Symbiotic Virus', 'TeardropLocket',
    'The Courier', 'Toxic Egg 2', 'White Beast Statue', 'Bird Faced Urn',
    'Calipers', 'CaptainsWheel', 'Champion Belt', 'Charon\'s Ashes',
    'CloakClasp', 'Dead Branch', 'Du-Vu Doll', 'Emotion Chip',
    'FossilizedHelix', 'Gambling Chip', 'Ginger', 'Girya', 'GoldenEye',
    'Ice Cream', 'Incense Burner', 'Lizard Tail', 'Magic Flower', 'Mango',
    'Old Coin', 'Peace Pipe', 'Pocketwatch', 'Prayer Wheel', 'Shovel',
    'StoneCalendar', 'The Specimen', 'Thread and Needle', 'Tingsha', 'Torii',
    'Tough Bandages', 'TungstenRod', 'Turnip', 'Unceasing Top',
    'WingedGreaves', 'Astrolabe', 'Black Blood', 'Black Star', 'Busted Crown',
    'Calling Bell', 'Coffee Dripper', 'Cursed Key', 'Ectoplasm', 'Empty Cage',
    'FrozenCore', 'Fusion Hammer', 'HolyWater', 'HoveringKite', 'Inserter',
    'Mark of Pain', 'Nuclear Battery', 'Pandora\'s Box',
    'Philosopher\'s Stone', 'Ring of the Serpent', 'Runic Cube', 'Runic Dome',
    'Runic Pyramid', 'SacredBark', 'SlaversCollar', 'Snecko Eye', 'Sozu',
    'Tiny House', 'Velvet Choker', 'VioletLotus', 'WristBlade', 'Bloody Idol',
    'CultistMask', 'Enchiridion', 'FaceOfCleric', 'Golden Idol', 'GremlinMask',
    'Mark of the Bloom', 'MutagenicStrength', 'Nloth\'s Gift', 'NlothsMask',
    'Necronomicon', 'NeowsBlessing', 'Nilry\'s Codex', 'Odd Mushroom',
    'Red Mask', 'Spirit Poop', 'SsserpentHead', 'WarpedTongs', 'Brimstone',
    'Cauldron', 'Chemical X', 'ClockworkSouvenir', 'DollysMirror',
    'Frozen Eye', 'HandDrill', 'Lee\'s Waffle', 'Medical Kit', 'Melange',
    'Membership Card', 'OrangePellets', 'Orrery', 'PrismaticShard',
    'Runic Capacitor', 'Sling', 'Strange Spoon', 'TheAbacus', 'Toolbox',
    'TwistedFunnel'
}

# the relics in the vanilla game for ironclad
BASE_GAME_IRONCLAD_RELICS = {
    'Burning Blood',
    'Akabeko', 'Anchor', 'Ancient Tea Set', 'Art of War', 'Bag of Marbles',
    'Bag of Preparation', 'Blood Vial',
    'Bronze Scales', 'Centennial Puzzle', 'CeramicFish',
    'Dream Catcher', 'Happy Flower', 'Juzu Bracelet', 'Lantern', 'MawBank',
    'MealTicket', 'Nunchaku', 'Oddly Smooth Stone', 'Omamori', 'Orichalcum',
    'Pen Nib', 'Potion Belt',
    'PreservedInsect', 'Red Skull', 'Regal Pillow',
    'Smiling Mask',
    'Strawberry', 'Boot', 'Tiny Chest', 'Toy Ornithopter', 'Vajra',
    'War Paint', 'Whetstone', 'Blue Candle', 'Bottled Flame',
    'Bottled Lightning', 'Bottled Tornado', 'Darkstone Periapt',
    'Eternal Feather', 'Frozen Egg 2', 'Gremlin Horn', 'HornCleat',
    'InkBottle', 'Kunai', 'Letter Opener', 'Matryoshka', 'Meat on the Bone',
    'Mercury Hourglass', 'Molten Egg 2', 'Mummified Hand',
    'Ornamental Fan', 'Pantograph', 'Paper Frog', 'Pear',
    'Question Card', 'Self Forming Clay', 'Shuriken', 'Singing Bowl',
    'StrikeDummy', 'Sundial',
    'The Courier', 'Toxic Egg 2', 'White Beast Statue', 'Bird Faced Urn',
    'Calipers', 'CaptainsWheel', 'Champion Belt', 'Charon\'s Ashes',
    'Dead Branch', 'Du-Vu Doll',
    'FossilizedHelix', 'Gambling Chip', 'Ginger', 'Girya',
    'Ice Cream', 'Incense Burner', 'Lizard Tail', 'Magic Flower', 'Mango',
    'Old Coin', 'Peace Pipe', 'Pocketwatch', 'Prayer Wheel', 'Shovel',
    'StoneCalendar', 'Thread and Needle', 'Torii',
    'TungstenRod', 'Turnip', 'Unceasing Top',
    'WingedGreaves', 'Astrolabe', 'Black Blood', 'Black Star', 'Busted Crown',
    'Calling Bell', 'Coffee Dripper', 'Cursed Key', 'Ectoplasm', 'Empty Cage',
    'FrozenCore', 'Fusion Hammer',
    'Mark of Pain', 'Pandora\'s Box',
    'Philosopher\'s Stone', 'Runic Cube', 'Runic Dome',
    'Runic Pyramid', 'SacredBark', 'SlaversCollar', 'Snecko Eye', 'Sozu',
    'Tiny House', 'Velvet Choker', 'Bloody Idol',
    'CultistMask', 'Enchiridion', 'FaceOfCleric', 'Golden Idol', 'GremlinMask',
    'Mark of the Bloom', 'MutagenicStrength', 'Nloth\'s Gift', 'NlothsMask',
    'Necronomicon', 'NeowsBlessing', 'Nilry\'s Codex', 'Odd Mushroom',
    'Red Mask', 'Spirit Poop', 'SsserpentHead', 'WarpedTongs', 'Brimstone',
    'Cauldron', 'Chemical X', 'ClockworkSouvenir', 'DollysMirror',
    'Frozen Eye', 'HandDrill', 'Lee\'s Waffle', 'Medical Kit',
    'Membership Card', 'OrangePellets', 'Orrery', 'PrismaticShard',
    'Sling', 'Strange Spoon', 'TheAbacus', 'Toolbox'
}

# the relics in the vanilla game for ironclad that actually make a difference in card selection
BASE_GAME_RELEVANT_IRONCLAD_RELICS = {
    'Bird Faced Urn',
    'Calipers', 'CaptainsWheel', 'Champion Belt', 'Charon\'s Ashes',
    'Dead Branch', 'Du-Vu Doll',
    'FossilizedHelix', 'Gambling Chip', 'Ginger', 'Girya',
    'Ice Cream', 'Incense Burner', 'Lizard Tail', 'Magic Flower', 'Mango',
    'Old Coin', 'Peace Pipe', 'Pocketwatch', 'Prayer Wheel', 'Shovel',
    'StoneCalendar', 'Thread and Needle', 'Torii',
    'TungstenRod', 'Turnip', 'Unceasing Top',
    'WingedGreaves'
}

# the potions in the vanilla game
BASE_GAME_POTIONS = {
    'BloodPotion', 'Poison Potion', 'FocusPotion', 'BottledMiracle',
    'Block Potion', 'Dexterity Potion', 'Energy Potion', 'Explosive Potion',
    'Fire Potion', 'Strength Potion', 'Swift Potion', 'Weak Potion',
    'FearPotion', 'AttackPotion', 'SkillPotion', 'PowerPotion',
    'ColorlessPotion', 'SteroidPotion', 'SpeedPotion', 'BlessingOfTheForge',
    'TestModSTS:PlaceholderPotion', 'ElixirPotion', 'CunningPotion',
    'PotionOfCapacity', 'StancePotion', 'Regen Potion', 'Ancient Potion',
    'LiquidBronze', 'GamblersBrew', 'EssenceOfSteel', 'DuplicationPotion',
    'DistilledChaos', 'LiquidMemories', 'HeartOfIron', 'GhostInAJar',
    'EssenceOfDarkness', 'Ambrosia', 'CultistPotion', 'Fruit Juice',
    'SneckoOil', 'FairyPotion', 'SmokeBomb', 'EntropicBrew'
}

# all the attack cards in the vanilla game
BASE_GAME_ATTACKS = {
    'Immolate', 'Anger', 'Cleave', 'Reaper', 'Iron Wave', 'Reckless Charge',
    'Hemokinesis', 'Body Slam', 'Blood for Blood', 'Clash', 'Thunderclap',
    'Pummel', 'Pommel Strike', 'Twin Strike', 'Bash', 'Clothesline', 'Rampage',
    'Sever Soul', 'Whirlwind', 'Fiend Fire', 'Headbutt', 'Wild Strike',
    'Heavy Blade', 'Searing Blow', 'Feed', 'Bludgeon', 'Perfected Strike',
    'Carnage', 'Dropkick', 'Sword Boomerang', 'Uppercut', 'Strike',
    'Grand Finale', 'Glass Knife', 'Underhanded Strike', 'Dagger Spray',
    'Bane', 'Unload', 'Dagger Throw', 'Choke', 'Poisoned Stab',
    'Endless Agony', 'Riddle With Holes', 'Skewer', 'Quick Slash', 'Finisher',
    'Die Die Die', 'Heel Hook', 'Eviscerate', 'Dash', 'Backstab', 'Slice',
    'Flechettes', 'Masterful Stab', 'Strike', 'Neutralize', 'Sucker Punch',
    'All Out Attack', 'Flying Knee', 'Predator', 'Go for the Eyes',
    'Core Surge', 'Ball Lightning', 'Sunder', 'Streamline', 'Compile Driver',
    'All For One', 'Blizzard', 'Barrage', 'Meteor Strike', 'Rebound', 'Melter',
    'Gash', 'Sweeping Beam', 'FTL', 'Rip and Tear', 'Lockon', 'Scrape',
    'Beam Cell', 'Cold Snap', 'Strike', 'Thunder Strike', 'Hyperbeam',
    'Doom and Gloom', 'Consecrate', 'BowlingBash', 'WheelKick',
    'FlyingSleeves', 'JustLucky', 'FlurryOfBlows', 'TalkToTheHand',
    'WindmillStrike', 'CarveReality', 'Wallop', 'SashWhip', 'Eruption',
    'LessonLearned', 'CutThroughFate', 'ReachHeaven', 'Ragnarok', 'FearNoEvil',
    'SandsOfTime', 'Conclude', 'FollowUp', 'Brilliance', 'CrushJoints',
    'Tantrum', 'Weave', 'SignatureMove', 'Strike', 'EmptyFist', 'Shiv',
    'Dramatic Entrance', 'RitualDagger', 'Bite', 'Smite', 'Expunger',
    'HandOfGreed', 'Flash of Steel', 'ThroughViolence', 'Swift Strike',
    'Mind Blast'
}

BASE_GAME_IRONCLAD_ATTACKS = {
    'Immolate', 'Anger', 'Cleave', 'Reaper', 'Iron Wave', 'Reckless Charge',
    'Hemokinesis', 'Body Slam', 'Blood for Blood', 'Clash', 'Thunderclap',
    'Pummel', 'Pommel Strike', 'Twin Strike', 'Bash', 'Clothesline', 'Rampage',
    'Sever Soul', 'Whirlwind', 'Fiend Fire', 'Headbutt', 'Wild Strike',
    'Heavy Blade', 'Searing Blow', 'Feed', 'Bludgeon', 'Perfected Strike',
    'Carnage', 'Dropkick', 'Sword Boomerang', 'Uppercut', 'Strike'
}

# all the attack cards and their upgrades in the vanilla game
BASE_GAME_ATTACKS_AND_UPGRADES = BASE_GAME_ATTACKS | {
    upgrade_card(x)
    for x in BASE_GAME_ATTACKS
} | {
    'Searing Blow+2', 'Searing Blow+3', 'Searing Blow+4', 'Searing Blow+5',
    'Searing Blow+6', 'Searing Blow+7', 'Searing Blow+8', 'Searing Blow+9',
    'Searing Blow+10', 'Searing Blow+11', 'Searing Blow+12', 'Searing Blow+13',
    'Searing Blow+14', 'Searing Blow+15', 'Searing Blow+16', 'Searing Blow+17'
}

# attack cards that cannot be added to the player's deck in the vanilla game
BASE_GAME_TEMP_ATTACKS = {'Shiv', 'Smite', 'Expunger', 'ThroughViolence'}

# attack cards and their upgrades that cannot be added to the player's deck in the vanilla game
BASE_GAME_TEMP_ATTACKS_AND_UPGRADES = BASE_GAME_TEMP_ATTACKS | {
    upgrade_card(x)
    for x in BASE_GAME_TEMP_ATTACKS
}

# attack cards that can be added to the player's deck in the vanilla game
BASE_GAME_DECK_ATTACKS = BASE_GAME_ATTACKS - BASE_GAME_TEMP_ATTACKS

# attack cards and their upgrades that can be added to the player's deck in the vanilla game
BASE_GAME_DECK_ATTACKS_AND_UPGRADES = BASE_GAME_ATTACKS_AND_UPGRADES - BASE_GAME_TEMP_ATTACKS_AND_UPGRADES

# same idea as attacks
BASE_GAME_SKILLS = {
    'Spot Weakness', 'Warcry', 'Offering', 'Exhume', 'Power Through',
    'Dual Wield', 'Flex', 'Infernal Blade', 'Intimidate', 'True Grit',
    'Impervious', 'Shrug It Off', 'Flame Barrier', 'Burning Pact', 'Shockwave',
    'Seeing Red', 'Disarm', 'Armaments', 'Havoc', 'Rage', 'Limit Break',
    'Entrench', 'Defend', 'Sentinel', 'Battle Trance', 'Second Wind',
    'Bloodletting', 'Ghostly Armor', 'Double Tap', 'Crippling Poison',
    'Cloak And Dagger', 'Storm of Steel', 'Deadly Poison', 'Leg Sweep',
    'Bullet Time', 'Catalyst', 'Tactician', 'Blade Dance', 'Deflect',
    'Night Terror', 'Expertise', 'Blur', 'Setup', 'Burst', 'Acrobatics',
    'Doppelganger', 'Adrenaline', 'Calculated Gamble', 'Escape Plan', 'Terror',
    'Phantasmal Killer', 'Malaise', 'Reflex', 'Survivor', 'Defend',
    'Corpse Explosion', 'Venomology', 'Bouncing Flask', 'Backflip',
    'Outmaneuver', 'Concentrate', 'Prepared', 'PiercingWail', 'Distraction',
    'Dodge and Roll', 'Genetic Algorithm', 'Zap', 'Steam Power', 'Fission',
    'Glacier', 'Consume', 'Redo', 'Fusion', 'Amplify', 'Reboot', 'Aggregate',
    'Chaos', 'Stack', 'Seek', 'Rainbow', 'Chill', 'BootSequence', 'Coolheaded',
    'Tempest', 'Turbo', 'Undo', 'Force Field', 'Darkness', 'Double Energy',
    'Reinforced Body', 'Conserve Battery', 'Defend', 'Dualcast',
    'Auto Shields', 'Reprogram', 'Hologram', 'Leap', 'Recycle', 'Skim',
    'White Noise', 'Multi-Cast', 'Steam', 'DeusExMachina', 'Vengeance',
    'Sanctity', 'Halt', 'Protect', 'Indignation', 'ThirdEye',
    'ForeignInfluence', 'Crescendo', 'SpiritShield', 'ClearTheMind',
    'EmptyBody', 'WreathOfFlame', 'Collect', 'InnerPeace', 'Omniscience',
    'Wish', 'DeceiveReality', 'Alpha', 'Vault', 'Scrawl', 'Blasphemy',
    'Defend', 'WaveOfTheHand', 'Meditate', 'Perseverance', 'Swivel', 'Worship',
    'Vigilance', 'PathToVictory', 'Evaluate', 'EmptyMind', 'Prostrate',
    'ConjureBlade', 'Judgement', 'Pray', 'Beta', 'Dark Shackles', 'J.A.X.',
    'PanicButton', 'Trip', 'FameAndFortune', 'Impatience', 'The Bomb',
    'Insight', 'Miracle', 'Blind', 'Bandage Up', 'Secret Technique',
    'Deep Breath', 'Violence', 'Secret Weapon', 'Apotheosis', 'Forethought',
    'Enlightenment', 'Purity', 'Panacea', 'Transmutation', 'Ghostly',
    'Chrysalis', 'Discovery', 'Finesse', 'Master of Strategy',
    'Good Instincts', 'Jack Of All Trades', 'Safety', 'Metamorphosis',
    'Thinking Ahead', 'Madness'
}

BASE_GAME_IRONCLAD_SKILLS = {
    'Spot Weakness', 'Warcry', 'Offering', 'Exhume', 'Power Through',
    'Dual Wield', 'Flex', 'Infernal Blade', 'Intimidate', 'True Grit',
    'Impervious', 'Shrug It Off', 'Flame Barrier', 'Burning Pact', 'Shockwave',
    'Seeing Red', 'Disarm', 'Armaments', 'Havoc', 'Rage', 'Limit Break',
    'Entrench', 'Defend', 'Sentinel', 'Battle Trance', 'Second Wind',
    'Bloodletting', 'Ghostly Armor', 'Double Tap'
}

BASE_GAME_SKILLS_AND_UPGRADES = BASE_GAME_SKILLS | {
    upgrade_card(x)
    for x in BASE_GAME_SKILLS
}

BASE_GAME_TEMP_SKILLS = {'Beta' 'Insight', 'Miracle', 'Safety'}

BASE_GAME_TEMP_SKILLS_AND_UPGRADES = BASE_GAME_TEMP_SKILLS | {
    upgrade_card(x)
    for x in BASE_GAME_TEMP_SKILLS
}

BASE_GAME_DECK_SKILLS = BASE_GAME_SKILLS - BASE_GAME_TEMP_SKILLS

BASE_GAME_DECK_SKILLS_AND_UPGRADES = BASE_GAME_SKILLS_AND_UPGRADES - BASE_GAME_TEMP_SKILLS_AND_UPGRADES

# same idea as attacks
BASE_GAME_POWERS = {
    'Inflame', 'Brutality', 'Juggernaut', 'Berserk', 'Metallicize', 'Combust',
    'Dark Embrace', 'Barricade', 'Feel No Pain', 'Corruption', 'Rupture',
    'Demon Form', 'Fire Breathing', 'Evolve', 'A Thousand Cuts', 'After Image',
    'Tools of the Trade', 'Caltrops', 'Wraith Form v2', 'Envenom',
    'Well Laid Plans', 'Noxious Fumes', 'Infinite Blades', 'Accuracy',
    'Footwork', 'Storm', 'Hello World', 'Creative AI', 'Echo Form',
    'Self Repair', 'Loop', 'Static Discharge', 'Heatsinks', 'Buffer',
    'Electrodynamics', 'Machine Learning', 'Biased Cognition', 'Capacitor',
    'Defragment', 'Wireheading', 'BattleHymn', 'DevaForm', 'LikeWater',
    'Establishment', 'Fasting2', 'Adaptation', 'MentalFortress', 'Study',
    'Devotion', 'Nirvana', 'MasterReality', 'Sadistic Nature', 'LiveForever',
    'BecomeAlmighty', 'Panache', 'Mayhem', 'Magnetism', 'Omega'
}

BASE_GAME_IRONCLAD_POWERS = {
    'Inflame', 'Brutality', 'Juggernaut', 'Berserk', 'Metallicize', 'Combust',
    'Dark Embrace', 'Barricade', 'Feel No Pain', 'Corruption', 'Rupture',
    'Demon Form', 'Fire Breathing', 'Evolve'
}

BASE_GAME_POWERS_AND_UPGRADES = BASE_GAME_POWERS | {
    upgrade_card(x)
    for x in BASE_GAME_POWERS
}

BASE_GAME_TEMP_POWERS = {'Omega'}

BASE_GAME_TEMP_POWERS_AND_UPGRADES = BASE_GAME_TEMP_POWERS | {
    upgrade_card(x)
    for x in BASE_GAME_TEMP_POWERS
}

BASE_GAME_DECK_POWERS = BASE_GAME_POWERS - BASE_GAME_TEMP_POWERS

BASE_GAME_DECK_POWERS_AND_UPGRADES = BASE_GAME_POWERS_AND_UPGRADES - BASE_GAME_TEMP_POWERS_AND_UPGRADES

# ironclad rare cards
BASE_GAME_IRONCLAD_RARES = {
    'Barricade', 'Berserk', 'Bludgeon', 'Brutality', 'Corruption', 'Demon Form', 'Double Tap',
    'Exhume', 'Feed', 'Fiend Fire', 'Immolate', 'Impervious', 'Jugernaut', 'Limit Break',
    'Offering', 'Reaper'
}

BASE_GAME_IRONCLAD_UNCOMMONS = {
    'Battle Trance', 'Blood for Blood', 'Bloodletting', 'Burning Pact', 'Carnage',
    'Combust', 'Dark Embrace', 'Disarm', 'Dropkick', 'Dual Wield', 'Entrench', 'Evolve',
    'Feel No Pain', 'Fire Breathing', 'Flame Barrier', 'Ghostly Armor', 'Hemokinesis',
    'Infernal Blade', 'Inflame', 'Intimidate', 'Metallicize', 'Power Through', 'Pummel',
    'Rage', 'Rampage', 'Reckless Charge', 'Rupture', 'Searing Blow', 'Second Wind',
    'Seeing Red', 'Sentinel', 'Sever Soul', 'Shockwave', 'Spot Weakness', 'Uppercut',
    'Whirlwind'
}

# curse cards in the game that can be added to the player's deck
BASE_GAME_CURSES = {
    'Regret', 'Writhe', 'AscendersBane', 'Decay', 'Necronomicurse', 'Pain',
    'Parasite', 'Doubt', 'Injury', 'Clumsy', 'CurseOfTheBell', 'Normality',
    'Pride', 'Shame'
}

# status cards in the game that cannot be added to the player's deck
BASE_GAME_STATUSES = {'Burn', 'Dazed', 'Slimed', 'Void', 'Wound'}

# status cards and their upgrades in the game that cannot be added to the player's deck
BASE_GAME_STATUSES_AND_UPGRADES = {
    'Burn', upgrade_card('Burn'), 'Dazed', 'Slimed', 'Void', 'Wound'
}

# cards and their upgrades in the game that can be added to the player's deck
BASE_GAME_DECK_AND_UPGRADES = BASE_GAME_DECK_ATTACKS_AND_UPGRADES | BASE_GAME_DECK_SKILLS_AND_UPGRADES | BASE_GAME_DECK_POWERS_AND_UPGRADES | BASE_GAME_CURSES

# all cards and their upgrades in the game
BASE_GAME_CARDS_AND_UPGRADES = BASE_GAME_ATTACKS_AND_UPGRADES | BASE_GAME_SKILLS_AND_UPGRADES | BASE_GAME_POWERS_AND_UPGRADES | BASE_GAME_CURSES | BASE_GAME_STATUSES_AND_UPGRADES

BASE_GAME_IRONCLAD_CARDS = BASE_GAME_IRONCLAD_ATTACKS | BASE_GAME_IRONCLAD_SKILLS | BASE_GAME_IRONCLAD_POWERS

# categories for one hot encoder
# categories are in alphabetical order and is the order used by OneHotEncoder
# categories are made up of only cards and relics that can actually be obtained
ALL_CARDS = list(BASE_GAME_DECK_AND_UPGRADES)
ALL_RELICS = list(BASE_GAME_RELICS)

ALL_CARDS.sort()
ALL_RELICS.sort()

ALL_IRONCLAD_CARDS = list(BASE_GAME_IRONCLAD_CARDS)
ALL_IRONCLAD_RELICS = list(BASE_GAME_IRONCLAD_RELICS)
ALL_RELEVANT_IRONCLAD_RELICS = list(BASE_GAME_RELEVANT_IRONCLAD_RELICS)

ALL_IRONCLAD_CARDS.sort()
ALL_IRONCLAD_RELICS.sort()
ALL_RELEVANT_IRONCLAD_RELICS.sort()

# %% [markdown]
# ### Game Constants Diagnostics
#
# In order to make the model, it is necessary to know the exact size of the input vector, which is dependant on the size of the card category and relic category.
#
# Print them out to the console so that their size can be known when making the model.
#
# Additionally, in order to use the model in the Java Slay the Spire mod, the lists of cards and relics needs to be formatted as Java code. So print that out here, so it can be copy/pasted into the code for the Java mod.

# %%
print('All cards', len(ALL_CARDS))
print('All relics', len(ALL_RELICS))
print('Ironclad cards', len(ALL_IRONCLAD_CARDS))
print('Ironclad relics', len(ALL_IRONCLAD_RELICS))
print('Relevant Ironclad relics', len(ALL_RELEVANT_IRONCLAD_RELICS))
print('\n')

card_quotes = ['\"%s\"' % x for x in ALL_CARDS]

print(', '.join(card_quotes), '\n')

relic_quotes = ['\"%s\"' % x for x in ALL_RELICS]

print(', '.join(relic_quotes), '\n')

ironclad_card_quotes = ['\"%s\"' % x for x in ALL_IRONCLAD_CARDS]

print(', '.join(ironclad_card_quotes), '\n')


ironclad_relic_quotes = ['\"%s\"' % x for x in ALL_IRONCLAD_RELICS]

print(', '.join(ironclad_relic_quotes), '\n')

ironclad_relevant_relic_quotes = ['\"%s\"' % x for x in ALL_RELEVANT_IRONCLAD_RELICS]

print(', '.join(ironclad_relevant_relic_quotes), '\n')
# Out:
# All cards 706
# All relics 178
# Ironclad cards 75
# Ironclad relics 150
# Relevant Ironclad relics 28
#
#
# "A Thousand Cuts", "A Thousand Cuts+1", "Accuracy", "Accuracy+1", "Acrobatics", "Acrobatics+1", "Adaptation", "Adaptation+1", "Adrenaline", "Adrenaline+1", "After Image", "After Image+1", "Aggregate", "Aggregate+1", "All For One", "All For One+1", "All Out Attack", "All Out Attack+1", "Alpha", "Alpha+1", "Amplify", "Amplify+1", "Anger", "Anger+1", "Apotheosis", "Apotheosis+1", "Armaments", "Armaments+1", "AscendersBane", "Auto Shields", "Auto Shields+1", "Backflip", "Backflip+1", "Backstab", "Backstab+1", "Ball Lightning", "Ball Lightning+1", "Bandage Up", "Bandage Up+1", "Bane", "Bane+1", "Barrage", "Barrage+1", "Barricade", "Barricade+1", "Bash", "Bash+1", "Battle Trance", "Battle Trance+1", "BattleHymn", "BattleHymn+1", "Beam Cell", "Beam Cell+1", "BecomeAlmighty", "BecomeAlmighty+1", "Berserk", "Berserk+1", "Beta", "Beta+1", "Biased Cognition", "Biased Cognition+1", "Bite", "Bite+1", "Blade Dance", "Blade Dance+1", "Blasphemy", "Blasphemy+1", "Blind", "Blind+1", "Blizzard", "Blizzard+1", "Blood for Blood", "Blood for Blood+1", "Bloodletting", "Bloodletting+1", "Bludgeon", "Bludgeon+1", "Blur", "Blur+1", "Body Slam", "Body Slam+1", "BootSequence", "BootSequence+1", "Bouncing Flask", "Bouncing Flask+1", "BowlingBash", "BowlingBash+1", "Brilliance", "Brilliance+1", "Brutality", "Brutality+1", "Buffer", "Buffer+1", "Bullet Time", "Bullet Time+1", "Burning Pact", "Burning Pact+1", "Burst", "Burst+1", "Calculated Gamble", "Calculated Gamble+1", "Caltrops", "Caltrops+1", "Capacitor", "Capacitor+1", "Carnage", "Carnage+1", "CarveReality", "CarveReality+1", "Catalyst", "Catalyst+1", "Chaos", "Chaos+1", "Chill", "Chill+1", "Choke", "Choke+1", "Chrysalis", "Chrysalis+1", "Clash", "Clash+1", "ClearTheMind", "ClearTheMind+1", "Cleave", "Cleave+1", "Cloak And Dagger", "Cloak And Dagger+1", "Clothesline", "Clothesline+1", "Clumsy", "Cold Snap", "Cold Snap+1", "Collect", "Collect+1", "Combust", "Combust+1", "Compile Driver", "Compile Driver+1", "Concentrate", "Concentrate+1", "Conclude", "Conclude+1", "ConjureBlade", "ConjureBlade+1", "Consecrate", "Consecrate+1", "Conserve Battery", "Conserve Battery+1", "Consume", "Consume+1", "Coolheaded", "Coolheaded+1", "Core Surge", "Core Surge+1", "Corpse Explosion", "Corpse Explosion+1", "Corruption", "Corruption+1", "Creative AI", "Creative AI+1", "Crescendo", "Crescendo+1", "Crippling Poison", "Crippling Poison+1", "CrushJoints", "CrushJoints+1", "CurseOfTheBell", "CutThroughFate", "CutThroughFate+1", "Dagger Spray", "Dagger Spray+1", "Dagger Throw", "Dagger Throw+1", "Dark Embrace", "Dark Embrace+1", "Dark Shackles", "Dark Shackles+1", "Darkness", "Darkness+1", "Dash", "Dash+1", "Deadly Poison", "Deadly Poison+1", "Decay", "DeceiveReality", "DeceiveReality+1", "Deep Breath", "Deep Breath+1", "Defend", "Defend+1", "Deflect", "Deflect+1", "Defragment", "Defragment+1", "Demon Form", "Demon Form+1", "DeusExMachina", "DeusExMachina+1", "DevaForm", "DevaForm+1", "Devotion", "Devotion+1", "Die Die Die", "Die Die Die+1", "Disarm", "Disarm+1", "Discovery", "Discovery+1", "Distraction", "Distraction+1", "Dodge and Roll", "Dodge and Roll+1", "Doom and Gloom", "Doom and Gloom+1", "Doppelganger", "Doppelganger+1", "Double Energy", "Double Energy+1", "Double Tap", "Double Tap+1", "Doubt", "Dramatic Entrance", "Dramatic Entrance+1", "Dropkick", "Dropkick+1", "Dual Wield", "Dual Wield+1", "Dualcast", "Dualcast+1", "Echo Form", "Echo Form+1", "Electrodynamics", "Electrodynamics+1", "EmptyBody", "EmptyBody+1", "EmptyFist", "EmptyFist+1", "EmptyMind", "EmptyMind+1", "Endless Agony", "Endless Agony+1", "Enlightenment", "Enlightenment+1", "Entrench", "Entrench+1", "Envenom", "Envenom+1", "Eruption", "Eruption+1", "Escape Plan", "Escape Plan+1", "Establishment", "Establishment+1", "Evaluate", "Evaluate+1", "Eviscerate", "Eviscerate+1", "Evolve", "Evolve+1", "Exhume", "Exhume+1", "Expertise", "Expertise+1", "FTL", "FTL+1", "FameAndFortune", "FameAndFortune+1", "Fasting2", "Fasting2+1", "FearNoEvil", "FearNoEvil+1", " ...
#
# "Akabeko", "Anchor", "Ancient Tea Set", "Art of War", "Astrolabe", "Bag of Marbles", "Bag of Preparation", "Bird Faced Urn", "Black Blood", "Black Star", "Blood Vial", "Bloody Idol", "Blue Candle", "Boot", "Bottled Flame", "Bottled Lightning", "Bottled Tornado", "Brimstone", "Bronze Scales", "Burning Blood", "Busted Crown", "Cables", "Calipers", "Calling Bell", "CaptainsWheel", "Cauldron", "Centennial Puzzle", "CeramicFish", "Champion Belt", "Charon's Ashes", "Chemical X", "CloakClasp", "ClockworkSouvenir", "Coffee Dripper", "Cracked Core", "CultistMask", "Cursed Key", "Damaru", "Darkstone Periapt", "DataDisk", "Dead Branch", "DollysMirror", "Dream Catcher", "Du-Vu Doll", "Ectoplasm", "Emotion Chip", "Empty Cage", "Enchiridion", "Eternal Feather", "FaceOfCleric", "FossilizedHelix", "Frozen Egg 2", "Frozen Eye", "FrozenCore", "Fusion Hammer", "Gambling Chip", "Ginger", "Girya", "Golden Idol", "GoldenEye", "Gremlin Horn", "GremlinMask", "HandDrill", "Happy Flower", "HolyWater", "HornCleat", "HoveringKite", "Ice Cream", "Incense Burner", "InkBottle", "Inserter", "Juzu Bracelet", "Kunai", "Lantern", "Lee's Waffle", "Letter Opener", "Lizard Tail", "Magic Flower", "Mango", "Mark of Pain", "Mark of the Bloom", "Matryoshka", "MawBank", "MealTicket", "Meat on the Bone", "Medical Kit", "Melange", "Membership Card", "Mercury Hourglass", "Molten Egg 2", "Mummified Hand", "MutagenicStrength", "Necronomicon", "NeowsBlessing", "Nilry's Codex", "Ninja Scroll", "Nloth's Gift", "NlothsMask", "Nuclear Battery", "Nunchaku", "Odd Mushroom", "Oddly Smooth Stone", "Old Coin", "Omamori", "OrangePellets", "Orichalcum", "Ornamental Fan", "Orrery", "Pandora's Box", "Pantograph", "Paper Crane", "Paper Frog", "Peace Pipe", "Pear", "Pen Nib", "Philosopher's Stone", "Pocketwatch", "Potion Belt", "Prayer Wheel", "PreservedInsect", "PrismaticShard", "PureWater", "Question Card", "Red Mask", "Red Skull", "Regal Pillow", "Ring of the Serpent", "Ring of the Snake", "Runic Capacitor", "Runic Cube", "Runic Dome", "Runic Pyramid", "SacredBark", "Self Forming Clay", "Shovel", "Shuriken", "Singing Bowl", "SlaversCollar", "Sling", "Smiling Mask", "Snake Skull", "Snecko Eye", "Sozu", "Spirit Poop", "SsserpentHead", "StoneCalendar", "Strange Spoon", "Strawberry", "StrikeDummy", "Sundial", "Symbiotic Virus", "TeardropLocket", "The Courier", "The Specimen", "TheAbacus", "Thread and Needle", "Tingsha", "Tiny Chest", "Tiny House", "Toolbox", "Torii", "Tough Bandages", "Toxic Egg 2", "Toy Ornithopter", "TungstenRod", "Turnip", "TwistedFunnel", "Unceasing Top", "Vajra", "Velvet Choker", "VioletLotus", "War Paint", "WarpedTongs", "Whetstone", "White Beast Statue", "WingedGreaves", "WristBlade", "Yang"
#
# "Anger", "Armaments", "Barricade", "Bash", "Battle Trance", "Berserk", "Blood for Blood", "Bloodletting", "Bludgeon", "Body Slam", "Brutality", "Burning Pact", "Carnage", "Clash", "Cleave", "Clothesline", "Combust", "Corruption", "Dark Embrace", "Defend", "Demon Form", "Disarm", "Double Tap", "Dropkick", "Dual Wield", "Entrench", "Evolve", "Exhume", "Feed", "Feel No Pain", "Fiend Fire", "Fire Breathing", "Flame Barrier", "Flex", "Ghostly Armor", "Havoc", "Headbutt", "Heavy Blade", "Hemokinesis", "Immolate", "Impervious", "Infernal Blade", "Inflame", "Intimidate", "Iron Wave", "Juggernaut", "Limit Break", "Metallicize", "Offering", "Perfected Strike", "Pommel Strike", "Power Through", "Pummel", "Rage", "Rampage", "Reaper", "Reckless Charge", "Rupture", "Searing Blow", "Second Wind", "Seeing Red", "Sentinel", "Sever Soul", "Shockwave", "Shrug It Off", "Spot Weakness", "Strike", "Sword Boomerang", "Thunderclap", "True Grit", "Twin Strike", "Uppercut", "Warcry", "Whirlwind", "Wild Strike"
#
# "Akabeko", "Anchor", "Ancient Tea Set", "Art of War", "Astrolabe", "Bag of Marbles", "Bag of Preparation", "Bird Faced Urn", "Black Blood", "Black Star", "Blood Vial", "Bloody Idol", "Blue Candle", "Boot", "Bottled Flame", "Bottled Lightning", "Bottled Tornado", "Brimstone", "Bronze Scales", "Burning Blood", "Busted Crown", "Calipers", "Calling Bell", "CaptainsWheel", "Cauldron", "Centennial Puzzle", "CeramicFish", "Champion Belt", "Charon's Ashes", "Chemical X", "ClockworkSouvenir", "Coffee Dripper", "CultistMask", "Cursed Key", "Darkstone Periapt", "Dead Branch", "DollysMirror", "Dream Catcher", "Du-Vu Doll", "Ectoplasm", "Empty Cage", "Enchiridion", "Eternal Feather", "FaceOfCleric", "FossilizedHelix", "Frozen Egg 2", "Frozen Eye", "FrozenCore", "Fusion Hammer", "Gambling Chip", "Ginger", "Girya", "Golden Idol", "Gremlin Horn", "GremlinMask", "HandDrill", "Happy Flower", "HornCleat", "Ice Cream", "Incense Burner", "InkBottle", "Juzu Bracelet", "Kunai", "Lantern", "Lee's Waffle", "Letter Opener", "Lizard Tail", "Magic Flower", "Mango", "Mark of Pain", "Mark of the Bloom", "Matryoshka", "MawBank", "MealTicket", "Meat on the Bone", "Medical Kit", "Membership Card", "Mercury Hourglass", "Molten Egg 2", "Mummified Hand", "MutagenicStrength", "Necronomicon", "NeowsBlessing", "Nilry's Codex", "Nloth's Gift", "NlothsMask", "Nunchaku", "Odd Mushroom", "Oddly Smooth Stone", "Old Coin", "Omamori", "OrangePellets", "Orichalcum", "Ornamental Fan", "Orrery", "Pandora's Box", "Pantograph", "Paper Frog", "Peace Pipe", "Pear", "Pen Nib", "Philosopher's Stone", "Pocketwatch", "Potion Belt", "Prayer Wheel", "PreservedInsect", "PrismaticShard", "Question Card", "Red Mask", "Red Skull", "Regal Pillow", "Runic Cube", "Runic Dome", "Runic Pyramid", "SacredBark", "Self Forming Clay", "Shovel", "Shuriken", "Singing Bowl", "SlaversCollar", "Sling", "Smiling Mask", "Snecko Eye", "Sozu", "Spirit Poop", "SsserpentHead", "StoneCalendar", "Strange Spoon", "Strawberry", "StrikeDummy", "Sundial", "The Courier", "TheAbacus", "Thread and Needle", "Tiny Chest", "Tiny House", "Toolbox", "Torii", "Toxic Egg 2", "Toy Ornithopter", "TungstenRod", "Turnip", "Unceasing Top", "Vajra", "Velvet Choker", "War Paint", "WarpedTongs", "Whetstone", "White Beast Statue", "WingedGreaves"
#
# "Bird Faced Urn", "Calipers", "CaptainsWheel", "Champion Belt", "Charon's Ashes", "Dead Branch", "Du-Vu Doll", "FossilizedHelix", "Gambling Chip", "Ginger", "Girya", "Ice Cream", "Incense Burner", "Lizard Tail", "Magic Flower", "Mango", "Old Coin", "Peace Pipe", "Pocketwatch", "Prayer Wheel", "Shovel", "StoneCalendar", "Thread and Needle", "Torii", "TungstenRod", "Turnip", "Unceasing Top", "WingedGreaves"

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import re
import numpy as np


def encode_list(list_to_encode, category):
    """
  Encodes a list of strings using the OneHotEncoder for a certain category.
  The number of times each string appears in the list being encoded is the value assigned to that string in the One-Hot Encoded vector.
  :param list_to_encode: list of strings to encode
  :param category: list of strings in the category in order
  """
    if len(list_to_encode) == 0:
        return np.zeros(len(category))
    np_array = np.array(list_to_encode)
    encoder = OneHotEncoder(categories=[category], sparse=False)
    n_by_1 = np_array.reshape(len(np_array), 1)
    onehot_encoded = encoder.fit_transform(n_by_1)
    summed = np.sum(onehot_encoded, axis=0)
    return summed


def encode_single(value, category):
    np_array = np.array([[value]])
    encoder = OneHotEncoder(categories=[category], sparse=False)
    onehot_encoded = encoder.fit_transform(np_array)
    collapsed = np.sum(onehot_encoded, axis=0)
    return collapsed


def generalize_strikes_and_defends(cards):
    """
  Modifies any character specific Strikes and Defends (e.g. Strike_R and Defend_R) into general Strikes and Defends (e.g. Strike and Defend).
  :param cards: the cards in the player deck that might need to be modified
  """
    for i, s in enumerate(cards):
        if s.startswith('Strike_') or s.startswith('Defend_'):
            cards[i] = re.sub('_.', '', s)


def unupgrade_cards(cards):
    for i, s in enumerate(cards):
        if s[-2] == '+':
            cards[i] = re.sub('\+.', '', s)


def encode_cards(cards):
    """
  Encodes a list of cards into a modified one-hot vector where each index represents how many of that card are in the deck.
  The vector has length of ALL_CARDS.
  :param cards: the cards in the player deck to be encoded into a vector
  """
    cards = np.array(cards)
    unupgrade_cards(cards)
    generalize_strikes_and_defends(cards)
    filter_arr = [(card in ALL_IRONCLAD_CARDS) for card in cards]
    cards = cards[filter_arr]
    return encode_list(cards, ALL_IRONCLAD_CARDS)


def encode_relics(relics):
    """
  Encodes a list of relics into a modified one-hot vector of length ALL_RELICS.
  If the relic is present in relics, it will be represented as 1 in the returned
  vector
  """
    relics = np.array(relics)
    filter_arr = [(relic in ALL_IRONCLAD_RELICS) for relic in relics]
    relics = relics[filter_arr]
    return encode_list(relics, ALL_IRONCLAD_RELICS)


def encode_sample_with_loop(sample):
    """
  Encode a single sample into a 1D input vector for the model.
  :param sample: the training sample as json data (i.e. nested dictionary/list structure in python)
  """
    deck = encode_cards(sample['deck'])
    relics = encode_relics(sample['relics'])

    noptions = np.array(sample['not_picked'])
    if sample['picked'] != 'SKIP' and sample['picked'] != 'Singing Bowl':
        noptions = np.append(noptions, [sample['picked']])

    options = encode_cards(noptions)
    options = np.append(options, [1.0])

    # return (np.append(deck, [sample['floor']]), options)
    return (np.append(np.append(deck, relics), [sample['floor']]), options)

# %%
import random


def preprocess_with_loop(data, log=True, log_freq=1000):
    """
  Pre-processes the data one sample at a time using loops.
  X has shape: (num_samples, training_vec_len)
  Y has shape: (num_samples)
  """
    processed_samples = []
    processed_aux = []
    y = []

    if log:
        print(f'Processing {len(data)} samples')

    for i, sample in enumerate(data):
        # logging
        if log and i % log_freq == 0:
            print(
                f'{((i / len(data)) * 100):.1f} % complete. => {i} of {len(data)}'
            )

        # only ironclad
        if sample['character'] != 'IRONCLAD':
            continue

        # no old relics
        if 'Dodecahedron' in sample['relics']:
            continue
            
        # actual processing into expected data format
        noptions = np.array(sample['not_picked'])
        if sample['picked'] != 'SKIP' and sample['picked'] != 'Singing Bowl':
            np.append(noptions, [sample['picked']])
        unupgrade_cards(noptions)
        failure = False
        for opt in noptions:
            if not opt in ALL_IRONCLAD_CARDS:
                failure = True
                break
        if failure or len(noptions) <= 1:
            continue

        if sample['picked'] != 'SKIP' and sample['picked'] != 'Singing Bowl':
            unupgraded_pick = sample['picked']
            if unupgraded_pick[-2] == '+':
                unupgraded_pick = re.sub('\+.', '', unupgraded_pick)
            if not unupgraded_pick in ALL_IRONCLAD_CARDS:
                continue
            encoded_picked = encode_cards([sample['picked']])
            encoded_picked = np.append(encoded_picked, [0.0])
        else:
            encoded_picked = np.zeros(len(ALL_IRONCLAD_CARDS) + 1)
            encoded_picked[len(encoded_picked) - 1] = 1.0

        (p_sample, p_aux) = encode_sample_with_loop(sample)
        processed_samples.append(p_sample)
        processed_aux.append(p_aux)
        y.append(encoded_picked)

    X1 = np.vstack(processed_samples)
    X2 = np.vstack(processed_aux)
    Y = np.vstack(y)
    return X1, X2, Y

# %%
X1, X2, Y = preprocess_with_loop(datas, log_freq=1000)
# Out:
# Processing 65575 samples
# 0.0 % complete. => 0 of 65575
# 1.5 % complete. => 1000 of 65575
# 3.0 % complete. => 2000 of 65575
# 4.6 % complete. => 3000 of 65575
# 6.1 % complete. => 4000 of 65575
# 7.6 % complete. => 5000 of 65575
# 9.1 % complete. => 6000 of 65575
# 10.7 % complete. => 7000 of 65575
# 12.2 % complete. => 8000 of 65575
# 13.7 % complete. => 9000 of 65575
# 15.2 % complete. => 10000 of 65575
# 16.8 % complete. => 11000 of 65575
# 18.3 % complete. => 12000 of 65575
# 19.8 % complete. => 13000 of 65575
# 21.3 % complete. => 14000 of 65575
# 22.9 % complete. => 15000 of 65575
# 24.4 % complete. => 16000 of 65575
# 25.9 % complete. => 17000 of 65575
# 27.4 % complete. => 18000 of 65575
# 29.0 % complete. => 19000 of 65575
# 30.5 % complete. => 20000 of 65575
# 32.0 % complete. => 21000 of 65575
# 33.5 % complete. => 22000 of 65575
# 35.1 % complete. => 23000 of 65575
# 36.6 % complete. => 24000 of 65575
# 38.1 % complete. => 25000 of 65575
# 39.6 % complete. => 26000 of 65575
# 41.2 % complete. => 27000 of 65575
# 42.7 % complete. => 28000 of 65575
# 44.2 % complete. => 29000 of 65575
# 45.7 % complete. => 30000 of 65575
# 47.3 % complete. => 31000 of 65575
# 48.8 % complete. => 32000 of 65575
# 50.3 % complete. => 33000 of 65575
# 51.8 % complete. => 34000 of 65575
# 53.4 % complete. => 35000 of 65575
# 54.9 % complete. => 36000 of 65575
# 56.4 % complete. => 37000 of 65575
# 57.9 % complete. => 38000 of 65575
# 59.5 % complete. => 39000 of 65575
# 61.0 % complete. => 40000 of 65575
# 62.5 % complete. => 41000 of 65575
# 64.0 % complete. => 42000 of 65575
# 65.6 % complete. => 43000 of 65575
# 67.1 % complete. => 44000 of 65575
# 68.6 % complete. => 45000 of 65575
# 70.1 % complete. => 46000 of 65575
# 71.7 % complete. => 47000 of 65575
# 73.2 % complete. => 48000 of 65575
# 74.7 % complete. => 49000 of 65575
# 76.2 % complete. => 50000 of 65575
# 77.8 % complete. => 51000 of 65575
# 79.3 % complete. => 52000 of 65575
# 80.8 % complete. => 53000 of 65575
# 82.3 % complete. => 54000 of 65575
# 83.9 % complete. => 55000 of 65575
# 85.4 % complete. => 56000 of 65575
# 86.9 % complete. => 57000 of 65575
# 88.4 % complete. => 58000 of 65575
# 90.0 % complete. => 59000 of 65575
# 91.5 % complete. => 60000 of 65575
# 93.0 % complete. => 61000 of 65575
# 94.5 % complete. => 62000 of 65575
# 96.1 % complete. => 63000 of 65575
# 97.6 % complete. => 64000 of 65575
# 99.1 % complete. => 65000 of 65575

# %%
import matplotlib.pyplot as plt

floors = []
for ele in X1:
    floors.append(ele[len(ele) - 1])

plt.hist(floors, bins=20)
# Out:
# (array([1819., 1473., 1159., 1650., 1375., 1897.,  682., 1189., 1008.,
#         1426., 1127., 1749., 1163.,  810.,  944., 1342., 1074.,   24.,
#          263.,    4.]),
#  array([ 1.  ,  3.85,  6.7 ,  9.55, 12.4 , 15.25, 18.1 , 20.95, 23.8 ,
#         26.65, 29.5 , 32.35, 35.2 , 38.05, 40.9 , 43.75, 46.6 , 49.45,
#         52.3 , 55.15, 58.  ]),
#  <BarContainer object of 20 artists>)

# %%
dict_counts = {}
for ele in X2:
    for i, ele2 in enumerate(ele):
        if ele2 > 0:
            if i in dict_counts:
                dict_counts[i] += 1
            else:
                dict_counts[i] = 1

for i in range(len(ALL_IRONCLAD_CARDS)):
    if i in dict_counts:
        print(ALL_IRONCLAD_CARDS[i], dict_counts[i])
    else:
        print(ALL_IRONCLAD_CARDS[i], "NOT FOUND")
# Out:
# Anger 1827
# Armaments 1786
# Barricade 527
# Bash NOT FOUND
# Battle Trance 712
# Berserk 468
# Blood for Blood 655
# Bloodletting 661
# Bludgeon 535
# Body Slam 1793
# Brutality 511
# Burning Pact 602
# Carnage 656
# Clash 1756
# Cleave 1802
# Clothesline 1798
# Combust 623
# Corruption 547
# Dark Embrace 650
# Defend NOT FOUND
# Demon Form 569
# Disarm 658
# Double Tap 506
# Dropkick 614
# Dual Wield 637
# Entrench 627
# Evolve 599
# Exhume 515
# Feed 544
# Feel No Pain 648
# Fiend Fire 519
# Fire Breathing 654
# Flame Barrier 664
# Flex 1809
# Ghostly Armor 648
# Havoc 1823
# Headbutt 1779
# Heavy Blade 1757
# Hemokinesis 609
# Immolate 555
# Impervious 588
# Infernal Blade 627
# Inflame 653
# Intimidate 658
# Iron Wave 1781
# Juggernaut 477
# Limit Break 536
# Metallicize 653
# Offering 583
# Perfected Strike 1800
# Pommel Strike 1793
# Power Through 730
# Pummel 646
# Rage 613
# Rampage 618
# Reaper 581
# Reckless Charge 633
# Rupture 637
# Searing Blow 629
# Second Wind 644
# Seeing Red 717
# Sentinel 645
# Sever Soul 619
# Shockwave 696
# Shrug It Off 1794
# Spot Weakness 694
# Strike NOT FOUND
# Sword Boomerang 1786
# Thunderclap 1794
# True Grit 1772
# Twin Strike 1831
# Uppercut 686
# Warcry 1758
# Whirlwind 671
# Wild Strike 1778

# %%
dict_counts = {}
for ele in Y:
    for i, ele2 in enumerate(ele):
        if ele2 > 0:
            if i in dict_counts:
                dict_counts[i] += 1
            else:
                dict_counts[i] = 1

for i in range(len(ALL_IRONCLAD_CARDS)):
    if i in dict_counts:
        print(ALL_IRONCLAD_CARDS[i], dict_counts[i])
    else:
        print(ALL_IRONCLAD_CARDS[i], "NOT FOUND")
# Out:
# Anger 182
# Armaments 336
# Barricade 180
# Bash NOT FOUND
# Battle Trance 344
# Berserk 79
# Blood for Blood 78
# Bloodletting 39
# Bludgeon 112
# Body Slam 252
# Brutality 44
# Burning Pact 167
# Carnage 165
# Clash 93
# Cleave 284
# Clothesline 215
# Combust 54
# Corruption 193
# Dark Embrace 137
# Defend NOT FOUND
# Demon Form 314
# Disarm 338
# Double Tap 170
# Dropkick 106
# Dual Wield 97
# Entrench 142
# Evolve 148
# Exhume 114
# Feed 237
# Feel No Pain 252
# Fiend Fire 144
# Fire Breathing 160
# Flame Barrier 334
# Flex 255
# Ghostly Armor 191
# Havoc 100
# Headbutt 282
# Heavy Blade 421
# Hemokinesis 49
# Immolate 233
# Impervious 316
# Infernal Blade 119
# Inflame 370
# Intimidate 112
# Iron Wave 186
# Juggernaut 138
# Limit Break 301
# Metallicize 262
# Offering 331
# Perfected Strike 333
# Pommel Strike 412
# Power Through 238
# Pummel 191
# Rage 113
# Rampage 97
# Reaper 353
# Reckless Charge 47
# Rupture 62
# Searing Blow 37
# Second Wind 137
# Seeing Red 206
# Sentinel 102
# Sever Soul 41
# Shockwave 341
# Shrug It Off 796
# Spot Weakness 346
# Strike NOT FOUND
# Sword Boomerang 353
# Thunderclap 235
# True Grit 306
# Twin Strike 332
# Uppercut 230
# Warcry 170
# Whirlwind 252
# Wild Strike 184

# %%
def scale_X(X_data):
    """
  Used with one hot encoded model
  """
    X_copy = np.copy(X_data)
    for sample in X_copy:
        deck_size = 0
        for i in range(len(ALL_IRONCLAD_CARDS)):
            deck_size += sample[i]
        for i in range(len(ALL_IRONCLAD_CARDS)):
            sample[i] /= deck_size
    return X_copy


X1_scaled = scale_X(X1)
X2_scaled = X2
Y_scaled = Y

# %%
import tensorflow.keras as keras
import tensorflow as tf
import os
import datetime
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
import sys

X1_train, X1_test, X2_train, X2_test, Y_train, Y_test = train_test_split(
    X1_scaled, X2_scaled, Y_scaled, test_size=0.2, shuffle=True)

train_size = len(Y_train)
test_size = len(Y_test)

batch_size = 1024

train_dataset = tf.data.Dataset.from_tensor_slices((X1_train, X2_train, Y_train))
train_dataset = train_dataset.batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((X1_test, X2_test, Y_test))
test_dataset = test_dataset.batch(batch_size)

## two input layers to the model, pass both to the loss function
# input = tf.keras.layers.Input(75 + 1, dtype=tf.float64)
input = tf.keras.layers.Input(75 + 28 + 1, dtype=tf.float64)
hidden = tf.keras.layers.Dense(100, activation='relu', dtype=tf.float64)(input)
drop = tf.keras.layers.Dropout(0, dtype=tf.float64)(hidden)
output = tf.keras.layers.Dense(75 + 1, dtype=tf.float64)(drop)
model = tf.keras.models.Model(inputs=input, outputs=output)


optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# random draft
# def random_draft_error(x1, x2, y):
#     r = np.random.rand(x2.shape[0], 75 + 1)
#     mr = tf.math.multiply(x2, r)
#     idx_y = K.argmax(y, axis=1)
#     idx_mr = K.argmax(mr, axis=1)
#     incorrect = K.not_equal(idx_y, idx_mr)
#     error = K.cast(incorrect, tf.float64)
#     return error

# rare draft
# def rare_draft_error(x1, x2, y):
    # multiply the options by a rare mask
    # if there is a non-zero entry, pick
    # randomly and then compare with the
    # real choice
    # this probably cannot be done as a tensor
    # operation and will require me to process
    # row by row

train_loss_results = []
train_error_results = []
num_epochs = 100

for epoch in range(num_epochs):
    epoch_loss_avg = tf.keras.metrics.Mean()
    epoch_failure_count = tf.keras.metrics.Sum()

    for x1, x2, y in train_dataset:
        with tf.GradientTape() as tape:
            y_ = model(x1, training=True)
            loss_value = K.sum(K.square(tf.math.subtract(y, tf.math.multiply(x2, y_))))
        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))
        epoch_loss_avg.update_state(loss_value)
        
        my_ = tf.math.multiply(x2, y_)
        idx_y = K.argmax(y, axis=1)
        idx_my_ = K.argmax(my_, axis=1)
        incorrect = K.not_equal(idx_y, idx_my_)
        error = K.cast(incorrect, tf.float64)
        epoch_failure_count.update_state(error)

    train_loss_results.append(epoch_loss_avg.result())
    train_error_results.append(epoch_failure_count.result())
    
    epoch_loss_avg_test = tf.keras.metrics.Mean()
    epoch_failure_count_test = tf.keras.metrics.Sum()
    
    for x1_t, x2_t, y_t in test_dataset:
        y__t = model(x1_t, training=False)
        loss_value = K.sum(K.square(tf.math.subtract(y_t, tf.math.multiply(x2_t, y__t))))
        epoch_loss_avg_test.update_state(loss_value)
        
        my__t = tf.math.multiply(x2_t, y__t)
        idx_y_t = K.argmax(y_t, axis=1)
        idx_my__t = K.argmax(my__t, axis=1)
        incorrect = K.not_equal(idx_y_t, idx_my__t)
        error = K.cast(incorrect, tf.float64)
        epoch_failure_count_test.update_state(error)
        
#     epoch_random_failure_count_test = tf.keras.metrics.Sum()
    
#     for x1_t, x2_t, y_t in test_dataset:
#         error = random_draft_error(x1_t, x2_t, y_t)
#         epoch_random_failure_count_test.update_state(error)

    # , random test failure {epoch_random_failure_count_test.result().numpy() / test_size}
    print(f'epoch {epoch}, train loss {epoch_loss_avg.result().numpy()}, train failure {epoch_failure_count.result().numpy() / train_size}, test loss {epoch_loss_avg_test.result().numpy()}, test failure {epoch_failure_count_test.result().numpy() / test_size}')
# Out:
# epoch 0, train loss 6407.5, train failure 0.7428136624957727, test loss 1605.55078125, test failure 0.6638863841298467
# epoch 1, train loss 1137.1124267578125, train failure 0.668301206177432, test loss 801.2283935546875, test failure 0.6882326420198377
# epoch 2, train loss 815.9166259765625, train failure 0.6208995603652351, test loss 686.963134765625, test failure 0.5858881875563571
# epoch 3, train loss 746.4113159179688, train failure 0.5725960996505467, test loss 655.4616088867188, test failure 0.5626690712353472
# epoch 4, train loss 721.2256469726562, train failure 0.5545598016007215, test loss 636.4306030273438, test failure 0.5527502254283138
# epoch 5, train loss 700.0474243164062, train failure 0.5398489460038327, test loss 620.9085693359375, test failure 0.5340396753832282
# epoch 6, train loss 684.0020751953125, train failure 0.526265359035058, test loss 608.9235229492188, test failure 0.5196122633002705
# epoch 7, train loss 673.5267944335938, train failure 0.518092661481231, test loss 602.4126586914062, test failure 0.5128494138863842
# epoch 8, train loss 666.81005859375, train failure 0.5145417653026716, test loss 598.3284301757812, test failure 0.5076645626690712
# epoch 9, train loss 661.9690551757812, train failure 0.5098072370645925, test loss 595.5589599609375, test failure 0.5042831379621281
# epoch 10, train loss 658.1171264648438, train failure 0.5041145304926163, test loss 593.5192260742188, test failure 0.5040577096483319
# epoch 11, train loss 654.8280029296875, train failure 0.5, test loss 591.7269287109375, test failure 0.5011271415689811
# epoch 12, train loss 652.0992431640625, train failure 0.49808364333220606, test loss 590.1415405273438, test failure 0.4995491433724076
# epoch 13, train loss 649.6452026367188, train failure 0.49628001352722356, test loss 589.0626831054688, test failure 0.49752028854824165
# epoch 14, train loss 647.4901733398438, train failure 0.4945327471536467, test loss 588.0560302734375, test failure 0.4961677186654644
# epoch 15, train loss 645.489990234375, train failure 0.491432758426333, test loss 587.4346923828125, test failure 0.4950405770964833
# epoch 16, train loss 643.6099243164062, train failure 0.48923458460151054, test loss 586.5853881835938, test failure 0.4939134355275023
# epoch 17, train loss 641.8394775390625, train failure 0.4879945891105851, test loss 585.8843994140625, test failure 0.49346257889990985
# epoch 18, train loss 640.1212768554688, train failure 0.48438732950062, test loss 585.1983642578125, test failure 0.49211000901713253
# epoch 19, train loss 638.4529418945312, train failure 0.4815691579303348, test loss 584.634033203125, test failure 0.49008115419296666
# epoch 20, train loss 636.8612060546875, train failure 0.47925825724270094, test loss 583.9392700195312, test failure 0.489404869251578
# epoch 21, train loss 635.2603149414062, train failure 0.4762709953781986, test loss 583.30126953125, test failure 0.49030658250676284
# epoch 22, train loss 633.763427734375, train failure 0.4758764513583587, test loss 582.9302978515625, test failure 0.4896302975653742
# epoch 23, train loss 632.2754516601562, train failure 0.4742419118475933, test loss 582.3876953125, test failure 0.4882777276825969
# epoch 24, train loss 630.786376953125, train failure 0.4729455529252621, test loss 581.84326171875, test failure 0.48692515779981965
# epoch 25, train loss 629.41455078125, train failure 0.4714237402773081, test loss 581.4874267578125, test failure 0.4876014427412083
# epoch 26, train loss 628.0487670898438, train failure 0.46956374704091985, test loss 581.009521484375, test failure 0.48692515779981965
# epoch 27, train loss 626.7813720703125, train failure 0.46787284409874874, test loss 580.5672607421875, test failure 0.486248872858431
# epoch 28, train loss 625.4844970703125, train failure 0.4663510314507947, test loss 580.21630859375, test failure 0.48467087466185754
# epoch 29, train loss 624.19189453125, train failure 0.4647164919400293, test loss 579.8328247070312, test failure 0.4839945897204689
# epoch 30, train loss 622.9579467773438, train failure 0.46274377184082965, test loss 579.4850463867188, test failure 0.48354373309287646
# epoch 31, train loss 621.7879638671875, train failure 0.46240559125239544, test loss 579.1050415039062, test failure 0.48196573489630296
# epoch 32, train loss 620.6224975585938, train failure 0.46003832713335585, test loss 578.922607421875, test failure 0.4824165915238954
# epoch 33, train loss 619.4913940429688, train failure 0.4584601510539962, test loss 578.5172729492188, test failure 0.48016230838593327
# epoch 34, train loss 618.348876953125, train failure 0.45654379438620224, test loss 578.2806396484375, test failure 0.47813345356176734
# epoch 35, train loss 617.2425537109375, train failure 0.455641979483711, test loss 578.0325927734375, test failure 0.47948602344454466
# epoch 36, train loss 616.1846923828125, train failure 0.4536128959531056, test loss 577.8304443359375, test failure 0.4776825969341749
# epoch 37, train loss 615.152587890625, train failure 0.45316198850186, test loss 577.7725219726562, test failure 0.47745716862037874
# epoch 38, train loss 614.1478881835938, train failure 0.4519219930109345, test loss 577.5319213867188, test failure 0.4776825969341749
# epoch 39, train loss 613.127685546875, train failure 0.45113290497125463, test loss 577.41162109375, test failure 0.47858431018935976
# epoch 40, train loss 612.1458740234375, train failure 0.4494983654604892, test loss 577.1050415039062, test failure 0.4767808836789901
# epoch 41, train loss 611.1710815429688, train failure 0.4492165483034607, test loss 576.9221801757812, test failure 0.47633002705139765
# epoch 42, train loss 610.2297973632812, train failure 0.4473565550670725, test loss 576.7183837890625, test failure 0.4754283137962128
# epoch 43, train loss 609.3063354492188, train failure 0.44690564761582685, test loss 576.5374755859375, test failure 0.47633002705139765
# epoch 44, train loss 608.3748779296875, train failure 0.44560928869349564, test loss 576.4197998046875, test failure 0.4754283137962128
# epoch 45, train loss 607.4749145507812, train failure 0.443636568594296, test loss 576.3040771484375, test failure 0.47633002705139765
# epoch 46, train loss 606.5498046875, train failure 0.4429602074174276, test loss 576.1573486328125, test failure 0.47520288548241657
# epoch 47, train loss 605.6825561523438, train failure 0.4416074850636907, test loss 576.0445556640625, test failure 0.4733994589720469
# epoch 48, train loss 604.8034057617188, train failure 0.44002930898433096, test loss 575.8467407226562, test failure 0.47294860234445446
# epoch 49, train loss 603.9296875, train failure 0.43833840604215984, test loss 575.8045654296875, test failure 0.4722723174030658
# epoch 50, train loss 603.0978393554688, train failure 0.4376056814338857, test loss 575.6646118164062, test failure 0.4736248872858431
# epoch 51, train loss 602.2814331054688, train failure 0.4363093225115545, test loss 575.6510009765625, test failure 0.4743011722272317
# epoch 52, train loss 601.4822998046875, train failure 0.4348438732950062, test loss 575.525634765625, test failure 0.4738503155996393
# epoch 53, train loss 600.6799926757812, train failure 0.433547514372675, test loss 575.3980712890625, test failure 0.4738503155996393
# epoch 54, train loss 599.9053344726562, train failure 0.43275842633299516, test loss 575.2412109375, test failure 0.4743011722272317
# epoch 55, train loss 599.0828857421875, train failure 0.4312366136850411, test loss 575.2282104492188, test failure 0.4738503155996393
# epoch 56, train loss 598.3419189453125, train failure 0.42982752789989853, test loss 575.2510986328125, test failure 0.4720468890892696
# epoch 57, train loss 597.59765625, train failure 0.42858753240897307, test loss 575.2390747070312, test failure 0.47294860234445446
# epoch 58, train loss 596.844970703125, train failure 0.4268402660353962, test loss 575.0599365234375, test failure 0.4718214607754734
# epoch 59, train loss 596.126708984375, train failure 0.42520572652463084, test loss 574.9901123046875, test failure 0.4731740306582507
# epoch 60, train loss 595.4180908203125, train failure 0.42430391162213954, test loss 574.9644165039062, test failure 0.4715960324616772
# epoch 61, train loss 594.7088012695312, train failure 0.4230075526998084, test loss 574.9374389648438, test failure 0.4722723174030658
# epoch 62, train loss 594.0244750976562, train failure 0.4219366475031, test loss 574.8665161132812, test failure 0.47249774571686204
# epoch 63, train loss 593.3674926757812, train failure 0.4212602863262315, test loss 574.8680419921875, test failure 0.4718214607754734
# epoch 64, train loss 592.722900390625, train failure 0.4209221057377973, test loss 574.964111328125, test failure 0.4704688908926961
# epoch 65, train loss 592.0470581054688, train failure 0.41973847367827755, test loss 574.9249877929688, test failure 0.47069431920649235
# epoch 66, train loss 591.3941650390625, train failure 0.41878029534438055, test loss 574.8373413085938, test failure 0.4715960324616772
# epoch 67, train loss 590.765380859375, train failure 0.4181602975989178, test loss 574.7635498046875, test failure 0.4720468890892696
# epoch 68, train loss 590.149169921875, train failure 0.4175966632848608, test loss 574.8131103515625, test failure 0.4731740306582507
# epoch 69, train loss 589.5391235351562, train failure 0.4165821215195581, test loss 574.7747192382812, test failure 0.4722723174030658
# epoch 70, train loss 588.9619140625, train failure 0.4162439409311239, test loss 574.9240112304688, test failure 0.4718214607754734
# epoch 71, train loss 588.3649291992188, train failure 0.4148348551459813, test loss 574.9371337890625, test failure 0.4718214607754734
# epoch 72, train loss 587.7842407226562, train failure 0.41415849396911286, test loss 574.9592895507812, test failure 0.47294860234445446
# epoch 73, train loss 587.2296752929688, train failure 0.41320031563521586, test loss 574.9227294921875, test failure 0.4727231740306583
# epoch 74, train loss 586.694091796875, train failure 0.41258031788975313, test loss 575.1434936523438, test failure 0.47452660054102797
# epoch 75, train loss 586.183837890625, train failure 0.4121294104385075, test loss 575.2113037109375, test failure 0.47520288548241657
# epoch 76, train loss 585.6467895507812, train failure 0.4116785029872619, test loss 575.2088623046875, test failure 0.4749774571686204
# epoch 77, train loss 585.1143798828125, train failure 0.4110585052417991, test loss 575.3622436523438, test failure 0.47475202885482415
# epoch 78, train loss 584.61669921875, train failure 0.41010032690790216, test loss 575.4747924804688, test failure 0.4767808836789901
# epoch 79, train loss 584.1035766601562, train failure 0.40914214857400516, test loss 575.6199951171875, test failure 0.47610459873760147
# epoch 80, train loss 583.591552734375, train failure 0.4091985120054109, test loss 575.7897338867188, test failure 0.4776825969341749
# epoch 81, train loss 583.1078491210938, train failure 0.40807124337729683, test loss 575.8372802734375, test failure 0.4792605951307484
# epoch 82, train loss 582.6348266601562, train failure 0.4075639724946455, test loss 575.946044921875, test failure 0.47858431018935976
# epoch 83, train loss 582.1685791015625, train failure 0.406887611317777, test loss 576.0286254882812, test failure 0.4790351668169522
# epoch 84, train loss 581.72021484375, train failure 0.4065494307293428, test loss 576.2822875976562, test failure 0.47858431018935976
# epoch 85, train loss 581.2481079101562, train failure 0.40598579641528576, test loss 576.493408203125, test failure 0.478809738503156
# epoch 86, train loss 580.780029296875, train failure 0.4050839815127945, test loss 576.4986572265625, test failure 0.4790351668169522
# epoch 87, train loss 580.3292846679688, train failure 0.40423853004170895, test loss 576.578125, test failure 0.47971145175834085
# epoch 88, train loss 579.9290771484375, train failure 0.4037876225904633, test loss 576.7372436523438, test failure 0.4792605951307484
# epoch 89, train loss 579.472412109375, train failure 0.4035621688648405, test loss 577.0004272460938, test failure 0.47971145175834085
# epoch 90, train loss 579.0301513671875, train failure 0.4031112614135949, test loss 577.0762939453125, test failure 0.4803877366997295
# epoch 91, train loss 578.5840454101562, train failure 0.4024349002367264, test loss 577.1746215820312, test failure 0.4806131650135257
# epoch 92, train loss 578.18212890625, train failure 0.40153308533423515, test loss 577.3609619140625, test failure 0.48174030658250677
# epoch 93, train loss 577.8048095703125, train failure 0.40046218013752677, test loss 577.5829467773438, test failure 0.4824165915238954
# epoch 94, train loss 577.3795776367188, train failure 0.3996730920978469, test loss 577.60302734375, test failure 0.48309287646528404
# epoch 95, train loss 577.029052734375, train failure 0.3996730920978469, test loss 577.8410034179688, test failure 0.4824165915238954
# epoch 96, train loss 576.5902099609375, train failure 0.39871491376394996, test loss 578.0144653320312, test failure 0.4833183047790803
# epoch 97, train loss 576.18359375, train failure 0.39865855033254427, test loss 578.1610107421875, test failure 0.48309287646528404
# epoch 98, train loss 575.759765625, train failure 0.3981512794498929, test loss 578.3622436523438, test failure 0.4839945897204689
# epoch 99, train loss 575.3753051757812, train failure 0.3977003719986473, test loss 578.5184326171875, test failure 0.4837691614066727
